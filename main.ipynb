# %%
# !pip install kaggle
# Out:
# ...
#      ---------------------------------------- 82.7/82.7 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#   Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# ...
#   Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# ...
#      -------------------------------------- 162.8/162.8 kB 4.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.2/78.2 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 66.9/66.9 kB 3.5 MB/s eta 0:00:00
# ...
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# ...
#   Running setup.py install for kaggle: started
#   Running setup.py install for kaggle: finished with status 'done'
# ...

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|██████████| 200k/200k [00:00<00:00, 595kB/s]
# 100%|██████████| 200k/200k [00:00<00:00, 580kB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall() #extract file to dir
zip_ref.close() #close file

# %%
import pandas as pd
df = pd.read_csv('orders.csv', na_values=['Not Available', 'unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
# df.rename(columns={'Order Id':'order_id', 'City':'city'})
df.columns=df.columns.str.lower()
# Out:
#       order id  order date       ship mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal code region         category  \
# ...

# %%
#replacing space with underscore
df.columns=df.columns.str.replace(' ','_')

# %%
#derive new columns discount price

df['discount']=df['list_price']*df['discount_percent']*0.01

# %%
#sale price = list_price - discount
df['sale_price'] = df['list_price'] - df['discount']

# %%
#profit
df['profit'] = df['sale_price'] - df['cost_price']

# %%
#convert order_date from object data type to datetime
df['order_date'] = pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
df.drop(columns=['list_price','cost_price','discount_percent'], inplace=True)

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
import mysql.connector

# Establish the connection
conn = mysql.connector.connect(
    host="127.0.0.1",       # Replace with your MySQL host, e.g., "localhost" or "127.0.0.1"
    user="root",    # Replace with your MySQL username
    password="Ayaz@786",# Replace with your MySQL password
    database="XYZ" # Replace with your MySQL database name
)

# Check if the connection was successful
if conn.is_connected():
    print("Connected to MySQL database")
else:
    print("Failed to connect")
# Out:
# Connected to MySQL database

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create an SQLAlchemy engine
engine = create_engine('mysql+mysqlconnector://root:Ayaz%40786@127.0.0.1/kaggle')
# Out:
# 9994

# %%
# Write the DataFrame to MySQL
df.to_sql(
    name='df_orders',    # Name of the table
    con=engine,          # SQLAlchemy engine
    index=False,         # Do not write DataFrame index as a column
    if_exists='append'  # add 'replace' if not exists if the table do not exists then 'append'
)
# Out:
# 9994
